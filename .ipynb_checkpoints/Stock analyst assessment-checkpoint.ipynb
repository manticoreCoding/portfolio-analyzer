# %%
import pandas as pd
import json
import requests

def loadsampledata():
    data = pd.read_csv('data\Positions - Default.csv')

    return data

data = loadsampledata()

symbols = data.Symbol.dropna().unique()
#symbols2 = data.dropna().Symbol.unique()

#pd.unique(data["Symbol"])

#data["Symbol"].unique()
#data.Symbol.unique()

print(len(symbols), symbols)
#print(len(symbols2), symbols2)
# Out:
# 32 ['MAXN' 'XEQT' 'GLDM' 'THNK' 'VEQT' 'XGRO' 'REAL' 'SNX' 'JWEL' 'EEMV' 'XSH'
#  'IEFA' 'OTEX' 'ZFL' 'ACWV' 'IIP.UN' 'BMY' 'XEF' 'VUS' 'VTI' 'ALA' 'BRKB'
#  'ENB' 'LIT' 'XIC' 'BIP.UN' 'BLX' 'T' 'BABA' 'RY' 'KO' 'ATD.B']

# %%
#api_token = 'your_api_token'
#api_url_base = 'https://api.digitalocean.com/v2/'

headers = {
    'x-rapidapi-key': "71a5d7c9a5msh0ce9fc09f6a1668p137554jsnde2c9287d2b4",
    'x-rapidapi-host': "apidojo-yahoo-finance-v1.p.rapidapi.com"
}

def check_url(url):
  url = urlparse(url)
  conn = http.client.HTTPConnection(url.netloc)
  conn.request("HEAD", url.path)
  r = conn.getresponse()
  if r.status == 200:
    return True
  else:
    return False

def get_analysis(symbol):
    url = "https://apidojo-yahoo-finance-v1.p.rapidapi.com/stock/v2/get-analysis"

    querystring = {"symbol": symbol}


    response = requests.request("GET", url, headers=headers, params=querystring)
    #response = requests.get(url, headers=headers, params=querystring)
    
#    print (response.headers)
    if response.status_code != 200:
        print("Error in response")
        return false
    
    elif response.headers['content-length'] == "0":       
        print(symbol + " symbol not found")
        
        return True
    
    else:
        #analysis = json.loads(response.text)
        analysis = response.json()
        
        #if analysis.hasOwnProperty('financialData'):
        if 'financialData' in analysis:
            #print(json.dumps(analysis, indent = 4, sort_keys=False))
            keys = ['targetLowPrice', 'targetMedianPrice', 'currentPrice', 'targetMeanPrice', 'targetHighPrice']
            
            for key in keys:
                if 'fmt' in analysis['financialData'][key]:
                    print(key + " = " + json.dumps(analysis['financialData'][key]['fmt'], indent = 4, sort_keys=False))
                else:
                    print(key + "value does not exist for " + symbol)
                    return False
            #return True
            return analysis['financialData']
    
        #elif analysis.hasOwnProperty('fundPerformance'):
        elif 'fundPerformance' in analysis:
            print(symbol + "is a fund/ETF")
            print(json.dumps(analysis['fundPerformance']['annualTotalReturns'], indent = 4, sort_keys=False))
            #return True
            return analysis['fundPerformance']['annualTotalReturns']
        
        
        else:
            print("New category")
            return True

    
#get_analysis("TSLA"), 
#get_analysis("XEQT")
get_analysis("GLDM")
# Out:
# GLDMis a fund/ETF
# {
#     "returns": [
#         {
#             "year": "2021",
#             "annualValue": {}
#         },
#         {
#             "year": "2020",
#             "annualValue": {
#                 "raw": 0.2394867,
#                 "fmt": "23.95%"
#             }
#         },
#         {
#             "year": "2019",
#             "annualValue": {
#                 "raw": 0.1862019,
#                 "fmt": "18.62%"
#             }
#         },
#         {
#             "year": "2018",
#             "annualValue": {}
#         }
#     ],
#     "returnsCat": []
# }
# {'returns': [{'annualValue': {}, 'year': '2021'},
#   {'annualValue': {'fmt': '23.95%', 'raw': 0.2394867}, 'year': '2020'},
#   {'annualValue': {'fmt': '18.62%', 'raw': 0.1862019}, 'year': '2019'},
#   {'annualValue': {}, 'year': '2018'}],
#  'returnsCat': []}

# %%
for symbol in symbols:
    print("Analyzing " + symbol )
    get_analysis(symbol)
    print("-----------")
# Out:
# Analyzing MAXN
# targetLowPrice = "15.00"
# targetMedianPrice = "23.00"
# currentPrice = "20.10"
# targetMeanPrice = "27.67"
# targetHighPrice = "45.00"
# -----------
# Analyzing XEQT
# XEQT symbol not found
# -----------
# Analyzing GLDM
# GLDMis a fund/ETF
# {"trailingReturns": {"threeMonth": {"raw": -0.028800001, "fmt": "-2.88%"}, "oneYear": {"raw": 0.0921, "fmt": "9.21%"}, "ytd": {"raw": -0.0924, "fmt": "-9.24%"}, "lastBearMkt": {"raw": 0, "fmt": "0.00%"}, "lastBullMkt": {"raw": 0, "fmt": "0.00%"}, "fiveYear": {"raw": 0, "fmt": "0.00%"}, "asOfDate": {"raw": 1614470400, "fmt": "2021-02-28"}, "tenYear": {"raw": 0, "fmt": "0.00%"}, "oneMonth": {"raw": -0.0627, "fmt": "-6.27%"}, "threeYear": {"raw": 0, "fmt": "0.00%"}}, "performanceOverview": {"bestThreeYrTotalReturn": {}, "morningStarReturnRating": {}, "ytdReturnPct": {"raw": -0.0762, "fmt": "-7.62%"}, "fiveYrAvgReturnPct": {}, "numYearsUp": {}, "worstOneYrTotalReturn": {}, "oneYearTotalReturn": {"raw": 0.0382, "fmt": "3.82%"}, "numYearsDown": {}, "asOfDate": {"raw": 1618272000, "fmt": "2021-04-13"}, "worstThreeYrTotalReturn": {}, "bestOneYrTotalReturn": {}, "threeYearTotalReturn": {"raw": 0, "fmt": "0.00%"}}, "riskOverviewStatistics": {"riskRating": {}, "riskStatistics": []}, "riskOverviewStatisticsCat": {"riskStatisticsCat": []}, "performanceOverviewCat": {"bestThreeYrTotalReturn": {}, "morningStarReturnRating": {}, "ytdReturnPct": {}, "fiveYrAvgReturnPct": {}, "numYearsUp": {}, "worstOneYrTotalReturn": {}, "numYearsDown": {}, "asOfDate": {}, "worstThreeYrTotalReturn": {}, "bestOneYrTotalReturn": {}}, "trailingReturnsCat": {"threeMonth": {"raw": 0, "fmt": "0.00%"}, "oneYear": {"raw": 0, "fmt": "0.00%"}, "ytd": {"raw": 0, "fmt": "0.00%"}, "lastBearMkt": {"raw": 0, "fmt": "0.00%"}, "lastBullMkt": {"raw": 0, "fmt": "0.00%"}, "fiveYear": {"raw": 0, "fmt": "0.00%"}, "tenYear": {"raw": 0, "fmt": "0.00%"}, "oneMonth": {"raw": 0, "fmt": "0.00%"}, "threeYear": {"raw": 0, "fmt": "0.00%"}}, "maxAge": 1, "pastQuarterlyReturns": {"returns": []}, "trailingReturnsNav": {"ytd": {"raw": -0.0787, "fmt": "-7.87%"}, "oneMonth": {"raw": -0.065, "fmt": "-6.50%"}, "threeMonth": {"raw": -0.0116, "fmt": "-1.16%"}, "oneYear": {"raw": 0.080699995, "fmt": "8.07%"}, "threeYear": {"raw": 0, "fmt": "0.00%"}, "fiveYear": {"raw": 0, "fmt": "0.00%"}, "tenYear": {"raw": 0, "fmt": "0.00%"}}, "annualTotalReturns": {"returns": [{"year": "2021", "annualValue": {}}, {"year": "2020", "annualValue": {"raw": 0.2394867, "fmt": "23.95%"}}, {"year": "2019", "annualValue": {"raw": 0.1862019, "fmt": "18.62%"}}, {"year": "2018", "annualValue": {}}], "returnsCat": []}}
# -----------
# Analyzing THNK
# THNKis a fund/ETF
# {}
# -----------
# Analyzing VEQT
# VEQT symbol not found
# -----------
# Analyzing XGRO
# XGRO symbol not found
# -----------
# Analyzing REAL
# targetLowPrice = "25.00"
# targetMedianPrice = "32.00"
# currentPrice = "23.71"
# targetMeanPrice = "30.46"
# targetHighPrice = "35.00"
# -----------
# Analyzing SNX
# targetLowPrice = "110.00"
# targetMedianPrice = "123.00"
# currentPrice = "124.20"
# targetMeanPrice = "123.00"
# targetHighPrice = "132.00"
# -----------
# Analyzing JWEL
# targetLowPricevalue does not exist for JWEL
# -----------
# Analyzing EEMV
# EEMVis a fund/ETF
# {"trailingReturns": {"threeMonth": {"raw": 0.070700005, "fmt": "7.07%"}, "oneYear": {"raw": 0.1985, "fmt": "19.85%"}, "ytd": {"raw": 0.0198, "fmt": "1.98%"}, "lastBearMkt": {"raw": 0, "fmt": "0.00%"}, "lastBullMkt": {"raw": 0, "fmt": "0.00%"}, "fiveYear": {"raw": 0.0854, "fmt": "8.54%"}, "asOfDate": {"raw": 1614470400, "fmt": "2021-02-28"}, "tenYear": {"raw": 0, "fmt": "0.00%"}, "oneMonth": {"raw": 0.0099, "fmt": "0.99%"}, "threeYear": {"raw": 0.032, "fmt": "3.20%"}}, "performanceOverview": {"bestThreeYrTotalReturn": {}, "morningStarReturnRating": {}, "ytdReturnPct": {"raw": 0.0428, "fmt": "4.28%"}, "fiveYrAvgReturnPct": {}, "numYearsUp": {}, "worstOneYrTotalReturn": {}, "oneYearTotalReturn": {"raw": 0.32349998, "fmt": "32.35%"}, "numYearsDown": {}, "asOfDate": {"raw": 1619049600, "fmt": "2021-04-22"}, "worstThreeYrTotalReturn": {}, "bestOneYrTotalReturn": {}, "threeYearTotalReturn": {"raw": 0.036, "fmt": "3.60%"}}, "riskOverviewStatistics": {"riskRating": {}, "riskStatistics": [{"year": "5y", "alpha": {"raw": -0.12, "fmt": "-0.12"}, "beta": {"raw": 0.77, "fmt": "0.77"}, "meanAnnualReturn": {"raw": 0.77, "fmt": "0.77"}, "rSquared": {"raw": 80.62, "fmt": "80.62"}, "stdDev": {"raw": 12.82, "fmt": "12.82"}, "sharpeRatio": {"raw": 0.62, "fmt": "0.62"}, "treynorRatio": {"raw": 9.84, "fmt": "9.84"}}, {"year": "3y", "alpha": {"raw": -1.61, "fmt": "-1.61"}, "beta": {"raw": 0.74, "fmt": "0.74"}, "meanAnnualReturn": {"raw": 0.32, "fmt": "0.32"}, "rSquared": {"raw": 86.82, "fmt": "86.82"}, "stdDev": {"raw": 14.02, "fmt": "14.02"}, "sharpeRatio": {"raw": 0.17, "fmt": "0.17"}, "treynorRatio": {"raw": 1.98, "fmt": "1.98"}}, {"year": "10y", "alpha": {"raw": 0, "fmt": "0"}, "beta": {"raw": 0, "fmt": "0"}, "meanAnnualReturn": {"raw": 0, "fmt": "0"}, "rSquared": {"raw": 0, "fmt": "0"}, "stdDev": {"raw": 0, "fmt": "0"}, "sharpeRatio": {"raw": 0, "fmt": "0"}, "treynorRatio": {"raw": 0, "fmt": "0"}}]}, "riskOverviewStatisticsCat": {"riskStatisticsCat": [{"year": "5y", "alpha": {"raw": -4.3, "fmt": "-4.3"}, "beta": {"raw": 1.09, "fmt": "1.09"}, "meanAnnualReturn": {"raw": 0.27, "fmt": "0.27"}, "rSquared": {"raw": 75.69, "fmt": "75.69"}, "stdDev": {"raw": 17.83, "fmt": "17.83"}, "sharpeRatio": {"raw": 0.18, "fmt": "0.18"}, "treynorRatio": {"raw": 1.47, "fmt": "1.47"}}, {"year": "3y", "alpha": {"raw": -1.88, "fmt": "-1.88"}, "beta": {"raw": 1.1, "fmt": "1.1"}, "meanAnnualReturn": {"raw": -0.07, "fmt": "-0.07"}, "rSquared": {"raw": 68.99, "fmt": "68.99"}, "stdDev": {"raw": 16.8, "fmt": "16.8"}, "sharpeRatio": {"raw": -0.06, "fmt": "-0.06"}, "treynorRatio": {"raw": -2.11, "fmt": "-2.11"}}, {"year": "10y", "alpha": {"raw": 2.04, "fmt": "2.04"}, "beta": {"raw": 1.18, "fmt": "1.18"}, "meanAnnualReturn": {"raw": 0.55, "fmt": "0.55"}, "rSquared": {"raw": 84.99, "fmt": "84.99"}, "stdDev": {"raw": 24.73, "fmt": "24.73"}, "sharpeRatio": {"raw": 0.24, "fmt": "0.24"}, "treynorRatio": {"raw": 2.33, "fmt": "2.33"}}]}, "performanceOverviewCat": {"bestThreeYrTotalReturn": {}, "morningStarReturnRating": {}, "ytdReturnPct": {"raw": 0.14829999, "fmt": "14.83%"}, "fiveYrAvgReturnPct": {"raw": 0.0165, "fmt": "1.65%"}, "numYearsUp": {}, "worstOneYrTotalReturn": {}, "numYearsDown": {}, "asOfDate": {}, "worstThreeYrTotalReturn": {}, "bestOneYrTotalReturn": {}}, "trailingReturnsCat": {"threeMonth": {"raw": 0.0704, "fmt": "7.04%"}, "oneYear": {"raw": 0.1554, "fmt": "15.54%"}, "ytd": {"raw": 0.14829999, "fmt": "14.83%"}, "lastBearMkt": {"raw": 0, "fmt": "0.00%"}, "lastBullMkt": {"raw": 0, "fmt": "0.00%"}, "fiveYear": {"raw": 0.0165, "fmt": "1.65%"}, "tenYear": {"raw": 0.0359, "fmt": "3.59%"}, "oneMonth": {"raw": 0.0101, "fmt": "1.01%"}, "threeYear": {"raw": -0.0218, "fmt": "-2.18%"}}, "maxAge": 1, "pastQuarterlyReturns": {"returns": []}, "trailingReturnsNav": {"ytd": {"raw": 0.0171, "fmt": "1.71%"}, "oneMonth": {"raw": 0.0097, "fmt": "0.97%"}, "threeMonth": {"raw": 0.0719, "fmt": "7.19%"}, "oneYear": {"raw": 0.2053, "fmt": "20.53%"}, "threeYear": {"raw": 0.028900001, "fmt": "2 ...
# -----------
# Analyzing XSH
# XSHis a fund/ETF
# {}
# -----------
# Analyzing IEFA
# IEFAis a fund/ETF
# {"trailingReturns": {"threeMonth": {"raw": 0.0428, "fmt": "4.28%"}, "oneYear": {"raw": 0.47509998, "fmt": "47.51%"}, "ytd": {"raw": 0.0428, "fmt": "4.28%"}, "lastBearMkt": {"raw": 0, "fmt": "0.00%"}, "lastBullMkt": {"raw": 0, "fmt": "0.00%"}, "fiveYear": {"raw": 0.0934, "fmt": "9.34%"}, "asOfDate": {"raw": 1617148800, "fmt": "2021-03-31"}, "tenYear": {"raw": 0, "fmt": "0.00%"}, "oneMonth": {"raw": 0.024500001, "fmt": "2.45%"}, "threeYear": {"raw": 0.0602, "fmt": "6.02%"}}, "performanceOverview": {"bestThreeYrTotalReturn": {}, "morningStarReturnRating": {}, "ytdReturnPct": {"raw": 0.070700005, "fmt": "7.07%"}, "fiveYrAvgReturnPct": {}, "numYearsUp": {}, "worstOneYrTotalReturn": {}, "oneYearTotalReturn": {"raw": 0.458, "fmt": "45.80%"}, "numYearsDown": {}, "asOfDate": {"raw": 1619049600, "fmt": "2021-04-22"}, "worstThreeYrTotalReturn": {}, "bestOneYrTotalReturn": {}, "threeYearTotalReturn": {"raw": 0.0651, "fmt": "6.51%"}}, "riskOverviewStatistics": {"riskRating": {}, "riskStatistics": [{"year": "5y", "alpha": {"raw": -0.44, "fmt": "-0.44"}, "beta": {"raw": 1.01, "fmt": "1.01"}, "meanAnnualReturn": {"raw": 0.84, "fmt": "0.84"}, "rSquared": {"raw": 96.63, "fmt": "96.63"}, "stdDev": {"raw": 14.99, "fmt": "14.99"}, "sharpeRatio": {"raw": 0.59, "fmt": "0.59"}, "treynorRatio": {"raw": 8.08, "fmt": "8.08"}}, {"year": "3y", "alpha": {"raw": -0.17, "fmt": "-0.17"}, "beta": {"raw": 1.01, "fmt": "1.01"}, "meanAnnualReturn": {"raw": 0.64, "fmt": "0.64"}, "rSquared": {"raw": 97.17, "fmt": "97.17"}, "stdDev": {"raw": 18.04, "fmt": "18.04"}, "sharpeRatio": {"raw": 0.35, "fmt": "0.35"}, "treynorRatio": {"raw": 4.9, "fmt": "4.9"}}, {"year": "10y", "alpha": {"raw": 0, "fmt": "0"}, "beta": {"raw": 0, "fmt": "0"}, "meanAnnualReturn": {"raw": 0, "fmt": "0"}, "rSquared": {"raw": 0, "fmt": "0"}, "stdDev": {"raw": 0, "fmt": "0"}, "sharpeRatio": {"raw": 0, "fmt": "0"}, "treynorRatio": {"raw": 0, "fmt": "0"}}]}, "riskOverviewStatisticsCat": {"riskStatisticsCat": [{"year": "5y", "alpha": {"raw": 1.34, "fmt": "1.34"}, "beta": {"raw": 0.95, "fmt": "0.95"}, "meanAnnualReturn": {"raw": 0.66, "fmt": "0.66"}, "rSquared": {"raw": 93.83, "fmt": "93.83"}, "stdDev": {"raw": 13.95, "fmt": "13.95"}, "sharpeRatio": {"raw": 0.57, "fmt": "0.57"}, "treynorRatio": {"raw": 7.64, "fmt": "7.64"}}, {"year": "3y", "alpha": {"raw": 0.72, "fmt": "0.72"}, "beta": {"raw": 1.01, "fmt": "1.01"}, "meanAnnualReturn": {"raw": 0.14, "fmt": "0.14"}, "rSquared": {"raw": 91.75, "fmt": "91.75"}, "stdDev": {"raw": 13.42, "fmt": "13.42"}, "sharpeRatio": {"raw": 0.15, "fmt": "0.15"}, "treynorRatio": {"raw": 1.18, "fmt": "1.18"}}, {"year": "10y", "alpha": {"raw": -0.3, "fmt": "-0.3"}, "beta": {"raw": 0.96, "fmt": "0.96"}, "meanAnnualReturn": {"raw": 0.3, "fmt": "0.3"}, "rSquared": {"raw": 93.95, "fmt": "93.95"}, "stdDev": {"raw": 19.03, "fmt": "19.03"}, "sharpeRatio": {"raw": 0.14, "fmt": "0.14"}, "treynorRatio": {"raw": 0.97, "fmt": "0.97"}}]}, "performanceOverviewCat": {"bestThreeYrTotalReturn": {}, "morningStarReturnRating": {}, "ytdReturnPct": {"raw": 0.041100003, "fmt": "4.11%"}, "fiveYrAvgReturnPct": {"raw": 0.0715, "fmt": "7.15%"}, "numYearsUp": {}, "worstOneYrTotalReturn": {}, "numYearsDown": {}, "asOfDate": {}, "worstThreeYrTotalReturn": {}, "bestOneYrTotalReturn": {}}, "trailingReturnsCat": {"threeMonth": {"raw": 0.056199998, "fmt": "5.62%"}, "oneYear": {"raw": 0.08189999, "fmt": "8.19%"}, "ytd": {"raw": 0.041100003, "fmt": "4.11%"}, "lastBearMkt": {"raw": 0, "fmt": "0.00%"}, "lastBullMkt": {"raw": 0, "fmt": "0.00%"}, "fiveYear": {"raw": 0.0715, "fmt": "7.15%"}, "tenYear": {"raw": 0.0176, "fmt": "1.76%"}, "oneMonth": {"raw": 0.0128, "fmt": "1.28%"}, "threeYear": {"raw": 0.0078, "fmt": "0.78%"}}, "maxAge": 1, "pastQuarterlyReturns": {"returns": []}, "trailingReturnsNav": {"ytd": {"raw": 0.0372, "fmt": "3.72%"}, "oneMonth": {"raw": 0.0233, "fmt": "2.33%"}, "threeMonth": {"raw": 0.0372, "fmt": "3.72%"}, "oneYear": {"raw": 0.4719, "fmt": "47.19%"}, "threeYear": {"raw": 0.0631, "fmt": "6. ...
# -----------
# Analyzing OTEX
# targetLowPrice = "51.00"
# targetMedianPrice = "58.00"
# currentPrice = "47.65"
# targetMeanPrice = "57.05"
# targetHighPrice = "60.00"
# -----------
# Analyzing ZFL
# ZFL symbol not found
# -----------
# Analyzing ACWV
# ACWVis a fund/ETF
# {"trailingReturns": {"threeMonth": {"raw": 0.018099999, "fmt": "1.81%"}, "oneYear": {"raw": 0.25129998, "fmt": "25.13%"}, "ytd": {"raw": 0.018099999, "fmt": "1.81%"}, "lastBearMkt": {"raw": 0, "fmt": "0.00%"}, "lastBullMkt": {"raw": 0, "fmt": "0.00%"}, "fiveYear": {"raw": 0.085, "fmt": "8.50%"}, "asOfDate": {"raw": 1617148800, "fmt": "2021-03-31"}, "tenYear": {"raw": 0, "fmt": "0.00%"}, "oneMonth": {"raw": 0.0482, "fmt": "4.82%"}, "threeYear": {"raw": 0.0798, "fmt": "7.98%"}}, "performanceOverview": {"bestThreeYrTotalReturn": {}, "morningStarReturnRating": {}, "ytdReturnPct": {"raw": 0.0511, "fmt": "5.11%"}, "fiveYrAvgReturnPct": {}, "numYearsUp": {}, "worstOneYrTotalReturn": {}, "oneYearTotalReturn": {"raw": 0.2024, "fmt": "20.24%"}, "numYearsDown": {}, "asOfDate": {"raw": 1619049600, "fmt": "2021-04-22"}, "worstThreeYrTotalReturn": {}, "bestOneYrTotalReturn": {}, "threeYearTotalReturn": {"raw": 0.0911, "fmt": "9.11%"}}, "riskOverviewStatistics": {"riskRating": {}, "riskStatistics": [{"year": "5y", "alpha": {"raw": 2.13, "fmt": "2.13"}, "beta": {"raw": 0.59, "fmt": "0.59"}, "meanAnnualReturn": {"raw": 0.73, "fmt": "0.73"}, "rSquared": {"raw": 67.85, "fmt": "67.85"}, "stdDev": {"raw": 10.52, "fmt": "10.52"}, "sharpeRatio": {"raw": 0.72, "fmt": "0.72"}, "treynorRatio": {"raw": 12.45, "fmt": "12.45"}}, {"year": "3y", "alpha": {"raw": 3.27, "fmt": "3.27"}, "beta": {"raw": 0.6, "fmt": "0.6"}, "meanAnnualReturn": {"raw": 0.71, "fmt": "0.71"}, "rSquared": {"raw": 74.66, "fmt": "74.66"}, "stdDev": {"raw": 12.4, "fmt": "12.4"}, "sharpeRatio": {"raw": 0.58, "fmt": "0.58"}, "treynorRatio": {"raw": 11.09, "fmt": "11.09"}}, {"year": "10y", "alpha": {"raw": 0, "fmt": "0"}, "beta": {"raw": 0, "fmt": "0"}, "meanAnnualReturn": {"raw": 0, "fmt": "0"}, "rSquared": {"raw": 0, "fmt": "0"}, "stdDev": {"raw": 0, "fmt": "0"}, "sharpeRatio": {"raw": 0, "fmt": "0"}, "treynorRatio": {"raw": 0, "fmt": "0"}}]}, "riskOverviewStatisticsCat": {"riskStatisticsCat": [{"year": "5y", "alpha": {"raw": 3.23, "fmt": "3.23"}, "beta": {"raw": 0.87, "fmt": "0.87"}, "meanAnnualReturn": {"raw": 0.77, "fmt": "0.77"}, "rSquared": {"raw": 89.84, "fmt": "89.84"}, "stdDev": {"raw": 13.12, "fmt": "13.12"}, "sharpeRatio": {"raw": 0.72, "fmt": "0.72"}, "treynorRatio": {"raw": 10.19, "fmt": "10.19"}}, {"year": "3y", "alpha": {"raw": 4.54, "fmt": "4.54"}, "beta": {"raw": 0.92, "fmt": "0.92"}, "meanAnnualReturn": {"raw": 0.45, "fmt": "0.45"}, "rSquared": {"raw": 87.26, "fmt": "87.26"}, "stdDev": {"raw": 12.44, "fmt": "12.44"}, "sharpeRatio": {"raw": 0.46, "fmt": "0.46"}, "treynorRatio": {"raw": 5.66, "fmt": "5.66"}}, {"year": "10y", "alpha": {"raw": 0.43, "fmt": "0.43"}, "beta": {"raw": 0.85, "fmt": "0.85"}, "meanAnnualReturn": {"raw": 0.33, "fmt": "0.33"}, "rSquared": {"raw": 90.95, "fmt": "90.95"}, "stdDev": {"raw": 17.05, "fmt": "17.05"}, "sharpeRatio": {"raw": 0.18, "fmt": "0.18"}, "treynorRatio": {"raw": 2.04, "fmt": "2.04"}}]}, "performanceOverviewCat": {"bestThreeYrTotalReturn": {}, "morningStarReturnRating": {}, "ytdReturnPct": {"raw": 0.1042, "fmt": "10.42%"}, "fiveYrAvgReturnPct": {"raw": 0.0877, "fmt": "8.77%"}, "numYearsUp": {}, "worstOneYrTotalReturn": {}, "numYearsDown": {}, "asOfDate": {}, "worstThreeYrTotalReturn": {}, "bestOneYrTotalReturn": {}}, "trailingReturnsCat": {"threeMonth": {"raw": 0.0475, "fmt": "4.75%"}, "oneYear": {"raw": 0.1514, "fmt": "15.14%"}, "ytd": {"raw": 0.1042, "fmt": "10.42%"}, "lastBearMkt": {"raw": 0, "fmt": "0.00%"}, "lastBullMkt": {"raw": 0, "fmt": "0.00%"}, "fiveYear": {"raw": 0.0877, "fmt": "8.77%"}, "tenYear": {"raw": 0.0252, "fmt": "2.52%"}, "oneMonth": {"raw": 0.0078, "fmt": "0.78%"}, "threeYear": {"raw": 0.0478, "fmt": "4.78%"}}, "maxAge": 1, "pastQuarterlyReturns": {"returns": []}, "trailingReturnsNav": {"ytd": {"raw": 0.0175, "fmt": "1.75%"}, "oneMonth": {"raw": 0.0467, "fmt": "4.67%"}, "threeMonth": {"raw": 0.0175, "fmt": "1.75%"}, "oneYear": {"raw": 0.246, "fmt": "24.60%"}, "threeYear": {"raw": 0.081, "fmt": "8.10%"}, "fiveYear ...
# -----------
# Analyzing IIP.UN
# IIP.UN symbol not found
# -----------
# Analyzing BMY
# targetLowPrice = "66.00"
# targetMedianPrice = "76.00"
# currentPrice = "66.01"
# targetMeanPrice = "76.00"
# targetHighPrice = "87.00"
# -----------
# Analyzing XEF
# XEF symbol not found
# -----------
# Analyzing VUS
# VUS symbol not found
# -----------
# Analyzing VTI
# VTIis a fund/ETF
# {"trailingReturns": {"threeMonth": {"raw": 0.0654, "fmt": "6.54%"}, "oneYear": {"raw": 0.629, "fmt": "62.90%"}, "ytd": {"raw": 0.0654, "fmt": "6.54%"}, "lastBearMkt": {"raw": 0, "fmt": "0.00%"}, "lastBullMkt": {"raw": 0, "fmt": "0.00%"}, "fiveYear": {"raw": 0.16690001, "fmt": "16.69%"}, "asOfDate": {"raw": 1617148800, "fmt": "2021-03-31"}, "tenYear": {"raw": 0.138, "fmt": "13.80%"}, "oneMonth": {"raw": 0.0365, "fmt": "3.65%"}, "threeYear": {"raw": 0.1717, "fmt": "17.17%"}}, "performanceOverview": {"bestThreeYrTotalReturn": {}, "morningStarReturnRating": {}, "ytdReturnPct": {"raw": 0.1148, "fmt": "11.48%"}, "fiveYrAvgReturnPct": {}, "numYearsUp": {}, "worstOneYrTotalReturn": {}, "oneYearTotalReturn": {"raw": 0.6099, "fmt": "60.99%"}, "numYearsDown": {}, "asOfDate": {"raw": 1619049600, "fmt": "2021-04-22"}, "worstThreeYrTotalReturn": {}, "bestOneYrTotalReturn": {}, "threeYearTotalReturn": {"raw": 0.1843, "fmt": "18.43%"}}, "riskOverviewStatistics": {"riskRating": {}, "riskStatistics": [{"year": "5y", "alpha": {"raw": -0.2, "fmt": "-0.2"}, "beta": {"raw": 1.04, "fmt": "1.04"}, "meanAnnualReturn": {"raw": 1.39, "fmt": "1.39"}, "rSquared": {"raw": 99.3, "fmt": "99.3"}, "stdDev": {"raw": 15.55, "fmt": "15.55"}, "sharpeRatio": {"raw": 1, "fmt": "1"}, "treynorRatio": {"raw": 14.89, "fmt": "14.89"}}, {"year": "3y", "alpha": {"raw": -0.26, "fmt": "-0.26"}, "beta": {"raw": 1.05, "fmt": "1.05"}, "meanAnnualReturn": {"raw": 1.48, "fmt": "1.48"}, "rSquared": {"raw": 99.44, "fmt": "99.44"}, "stdDev": {"raw": 19.31, "fmt": "19.31"}, "sharpeRatio": {"raw": 0.84, "fmt": "0.84"}, "treynorRatio": {"raw": 15.04, "fmt": "15.04"}}, {"year": "10y", "alpha": {"raw": -0.54, "fmt": "-0.54"}, "beta": {"raw": 1.04, "fmt": "1.04"}, "meanAnnualReturn": {"raw": 1.17, "fmt": "1.17"}, "rSquared": {"raw": 99.25, "fmt": "99.25"}, "stdDev": {"raw": 14.14, "fmt": "14.14"}, "sharpeRatio": {"raw": 0.94, "fmt": "0.94"}, "treynorRatio": {"raw": 12.7, "fmt": "12.7"}}]}, "riskOverviewStatisticsCat": {"riskStatisticsCat": [{"year": "5y", "alpha": {"raw": -0.48, "fmt": "-0.48"}, "beta": {"raw": 1, "fmt": "1"}, "meanAnnualReturn": {"raw": 1.28, "fmt": "1.28"}, "rSquared": {"raw": 95.34, "fmt": "95.34"}, "stdDev": {"raw": 11.38, "fmt": "11.38"}, "sharpeRatio": {"raw": 1.34, "fmt": "1.34"}, "treynorRatio": {"raw": 15.73, "fmt": "15.73"}}, {"year": "3y", "alpha": {"raw": -0.65, "fmt": "-0.65"}, "beta": {"raw": 0.98, "fmt": "0.98"}, "meanAnnualReturn": {"raw": 0.86, "fmt": "0.86"}, "rSquared": {"raw": 94.06, "fmt": "94.06"}, "stdDev": {"raw": 10.9, "fmt": "10.9"}, "sharpeRatio": {"raw": 0.94, "fmt": "0.94"}, "treynorRatio": {"raw": 10.38, "fmt": "10.38"}}, {"year": "10y", "alpha": {"raw": 0.15, "fmt": "0.15"}, "beta": {"raw": 1, "fmt": "1"}, "meanAnnualReturn": {"raw": 0.69, "fmt": "0.69"}, "rSquared": {"raw": 96.99, "fmt": "96.99"}, "stdDev": {"raw": 15.42, "fmt": "15.42"}, "sharpeRatio": {"raw": 0.48, "fmt": "0.48"}, "treynorRatio": {"raw": 6.54, "fmt": "6.54"}}]}, "performanceOverviewCat": {"bestThreeYrTotalReturn": {}, "morningStarReturnRating": {}, "ytdReturnPct": {"raw": 0.075, "fmt": "7.50%"}, "fiveYrAvgReturnPct": {"raw": 0.1576, "fmt": "15.76%"}, "numYearsUp": {}, "worstOneYrTotalReturn": {}, "numYearsDown": {}, "asOfDate": {}, "worstThreeYrTotalReturn": {}, "bestOneYrTotalReturn": {}}, "trailingReturnsCat": {"threeMonth": {"raw": 0.032, "fmt": "3.20%"}, "oneYear": {"raw": 0.1345, "fmt": "13.45%"}, "ytd": {"raw": 0.075, "fmt": "7.50%"}, "lastBearMkt": {"raw": 0, "fmt": "0.00%"}, "lastBullMkt": {"raw": 0, "fmt": "0.00%"}, "fiveYear": {"raw": 0.1576, "fmt": "15.76%"}, "tenYear": {"raw": 0.0733, "fmt": "7.33%"}, "oneMonth": {"raw": -0.0025, "fmt": "-0.25%"}, "threeYear": {"raw": 0.1014, "fmt": "10.14%"}}, "maxAge": 1, "pastQuarterlyReturns": {"returns": []}, "trailingReturnsNav": {"ytd": {"raw": 0.0643, "fmt": "6.43%"}, "oneMonth": {"raw": 0.0348, "fmt": "3.48%"}, "threeMonth": {"raw": 0.0643, "fmt": "6.43%"}, "oneYear": {"raw": 0.6272, "fmt": "62.72%"}, "threeYear": {"r ...
# -----------
# Analyzing ALA
# ALAis a fund/ETF
# {}
# -----------
# Analyzing BRKB
# BRKB symbol not found
# -----------
# Analyzing ENB
# targetLowPrice = "31.16"
# targetMedianPrice = "42.85"
# currentPrice = "37.09"
# targetMeanPrice = "41.66"
# targetHighPrice = "49.08"
# -----------
# Analyzing LIT
# LITis a fund/ETF
# {"trailingReturns": {"threeMonth": {"raw": 0.16520001, "fmt": "16.52%"}, "oneYear": {"raw": 1.1818, "fmt": "118.18%"}, "ytd": {"raw": -0.0183, "fmt": "-1.83%"}, "lastBearMkt": {"raw": 0, "fmt": "0.00%"}, "lastBullMkt": {"raw": 0, "fmt": "0.00%"}, "fiveYear": {"raw": 0.2898, "fmt": "28.98%"}, "asOfDate": {"raw": 1614470400, "fmt": "2021-02-28"}, "tenYear": {"raw": 0.045300003, "fmt": "4.53%"}, "oneMonth": {"raw": -0.0735, "fmt": "-7.35%"}, "threeYear": {"raw": 0.2314, "fmt": "23.14%"}}, "performanceOverview": {"bestThreeYrTotalReturn": {}, "morningStarReturnRating": {}, "ytdReturnPct": {"raw": 0.0037, "fmt": "0.37%"}, "fiveYrAvgReturnPct": {}, "numYearsUp": {}, "worstOneYrTotalReturn": {}, "oneYearTotalReturn": {"raw": 1.6791999, "fmt": "167.92%"}, "numYearsDown": {}, "asOfDate": {"raw": 1619049600, "fmt": "2021-04-22"}, "worstThreeYrTotalReturn": {}, "bestOneYrTotalReturn": {}, "threeYearTotalReturn": {"raw": 0.24360001, "fmt": "24.36%"}}, "riskOverviewStatistics": {"riskRating": {}, "riskStatistics": [{"year": "5y", "alpha": {"raw": 9.82, "fmt": "9.82"}, "beta": {"raw": 1.38, "fmt": "1.38"}, "meanAnnualReturn": {"raw": 2.44, "fmt": "2.44"}, "rSquared": {"raw": 57.97, "fmt": "57.97"}, "stdDev": {"raw": 26.6, "fmt": "26.6"}, "sharpeRatio": {"raw": 1.05, "fmt": "1.05"}, "treynorRatio": {"raw": 20.29, "fmt": "20.29"}}, {"year": "3y", "alpha": {"raw": 9.86, "fmt": "9.86"}, "beta": {"raw": 1.42, "fmt": "1.42"}, "meanAnnualReturn": {"raw": 2.13, "fmt": "2.13"}, "rSquared": {"raw": 65.22, "fmt": "65.22"}, "stdDev": {"raw": 31.62, "fmt": "31.62"}, "sharpeRatio": {"raw": 0.76, "fmt": "0.76"}, "treynorRatio": {"raw": 14.94, "fmt": "14.94"}}, {"year": "10y", "alpha": {"raw": -5.87, "fmt": "-5.87"}, "beta": {"raw": 1.51, "fmt": "1.51"}, "meanAnnualReturn": {"raw": 0.68, "fmt": "0.68"}, "rSquared": {"raw": 61.79, "fmt": "61.79"}, "stdDev": {"raw": 27.04, "fmt": "27.04"}, "sharpeRatio": {"raw": 0.28, "fmt": "0.28"}, "treynorRatio": {"raw": 2.64, "fmt": "2.64"}}]}, "riskOverviewStatisticsCat": {"riskStatisticsCat": [{"year": "5y", "alpha": {"raw": -9.35, "fmt": "-9.35"}, "beta": {"raw": 1.33, "fmt": "1.33"}, "meanAnnualReturn": {"raw": 0.42, "fmt": "0.42"}, "rSquared": {"raw": 65.69, "fmt": "65.69"}, "stdDev": {"raw": 20.72, "fmt": "20.72"}, "sharpeRatio": {"raw": 0.31, "fmt": "0.31"}, "treynorRatio": {"raw": 3.06, "fmt": "3.06"}}, {"year": "3y", "alpha": {"raw": -7.11, "fmt": "-7.11"}, "beta": {"raw": 1.32, "fmt": "1.32"}, "meanAnnualReturn": {"raw": 0.03, "fmt": "0.03"}, "rSquared": {"raw": 61.16, "fmt": "61.16"}, "stdDev": {"raw": 20.01, "fmt": "20.01"}, "sharpeRatio": {"raw": 0.05, "fmt": "0.05"}, "treynorRatio": {"raw": -0.95, "fmt": "-0.95"}}, {"year": "10y", "alpha": {"raw": -0.04, "fmt": "-0.04"}, "beta": {"raw": 1.28, "fmt": "1.28"}, "meanAnnualReturn": {"raw": 0.59, "fmt": "0.59"}, "rSquared": {"raw": 75.15, "fmt": "75.15"}, "stdDev": {"raw": 25.59, "fmt": "25.59"}, "sharpeRatio": {"raw": 0.26, "fmt": "0.26"}, "treynorRatio": {"raw": 2.49, "fmt": "2.49"}}]}, "performanceOverviewCat": {"bestThreeYrTotalReturn": {}, "morningStarReturnRating": {}, "ytdReturnPct": {"raw": 0.2041, "fmt": "20.41%"}, "fiveYrAvgReturnPct": {"raw": 0.032, "fmt": "3.20%"}, "numYearsUp": {}, "worstOneYrTotalReturn": {}, "numYearsDown": {}, "asOfDate": {}, "worstThreeYrTotalReturn": {}, "bestOneYrTotalReturn": {}}, "trailingReturnsCat": {"threeMonth": {"raw": 0.0546, "fmt": "5.46%"}, "oneYear": {"raw": 0.22790001, "fmt": "22.79%"}, "ytd": {"raw": 0.2041, "fmt": "20.41%"}, "lastBearMkt": {"raw": 0, "fmt": "0.00%"}, "lastBullMkt": {"raw": 0, "fmt": "0.00%"}, "fiveYear": {"raw": 0.032, "fmt": "3.20%"}, "tenYear": {"raw": 0.0369, "fmt": "3.69%"}, "oneMonth": {"raw": 0.0047, "fmt": "0.47%"}, "threeYear": {"raw": -0.0154, "fmt": "-1.54%"}}, "maxAge": 1, "pastQuarterlyReturns": {"returns": []}, "trailingReturnsNav": {"ytd": {"raw": -0.0126, "fmt": "-1.26%"}, "oneMonth": {"raw": -0.0789, "fmt": "-7.89%"}, "threeMonth": {"raw": 0.1715, "fmt": "17.15%"}, "oneYear": {"ra ...
# -----------
# Analyzing XIC
# XIC symbol not found
# -----------
# Analyzing BIP.UN
# BIP.UN symbol not found
# -----------
# Analyzing BLX
# targetLowPrice = "18.00"
# targetMedianPrice = "18.00"
# currentPrice = "14.65"
# targetMeanPrice = "18.00"
# targetHighPrice = "18.00"
# -----------
# Analyzing T
# targetLowPrice = "16.00"
# targetMedianPrice = "30.00"
# currentPrice = "31.40"
# targetMeanPrice = "29.55"
# targetHighPrice = "36.00"
# -----------
# Analyzing BABA
# targetLowPrice = "249.94"
# targetMedianPrice = "310.92"
# currentPrice = "232.08"
# targetMeanPrice = "314.81"
# targetHighPrice = "387.90"
# -----------
# Analyzing RY
# targetLowPrice = "80.62"
# targetMedianPrice = "88.28"
# currentPrice = "93.46"
# targetMeanPrice = "88.28"
# targetHighPrice = "93.56"
# -----------
# Analyzing KO
# targetLowPrice = "53.00"
# targetMedianPrice = "60.00"
# currentPrice = "54.47"
# targetMeanPrice = "59.36"
# targetHighPrice = "67.00"
# -----------
# Analyzing ATD.B
# ATD.B symbol not found
# -----------
